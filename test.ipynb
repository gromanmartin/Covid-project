# %%
import pandas as pd
url = 'https://onemocneni-aktualne.mzcr.cz/api/v2/covid-19/nakazeni-vyleceni-umrti-testy.csv'
df = pd.read_csv(url)

# %%
df['datum'] = pd.to_datetime(df['datum'])

# %%
df[(df['datum']>=pd.Timestamp('2021-01-01')) & (df['datum'] <= pd.Timestamp('2021-01-10'))]
# Out:
#          datum  kumulativni_pocet_nakazenych  kumulativni_pocet_vylecenych  \
# 340 2021-01-01                        735734                        639402
# 341 2021-01-02                        740719                        650544
# 342 2021-01-03                        746987                        652632
# 343 2021-01-04                        759946                        655022
# 344 2021-01-05                        777353                        658823
# 345 2021-01-06                        795128                        663747
# 346 2021-01-07                        810013                        678245
# 347 2021-01-08                        823116                        694168
# 348 2021-01-09                        831559                        710348
# 349 2021-01-10                        835874                        719070
#
#      kumulativni_pocet_umrti  kumulativni_pocet_testu  \
# 340                    12120                  3820851
# 341                    12272                  3834300
# 342                    12413                  3849622
# 343                    12563                  3884799
# 344                    12743                  3928817
# 345                    12902                  3967866
# 346                    13088                  4006840
# 347                    13284                  4045603
# 348                    13445                  4066684
# 349                    13629                  4079001
#
#      kumulativni_pocet_ag_testu  prirustkovy_pocet_nakazenych  \
# 340                      857277                          3446
# 341                      872806                          4985
# 342                      887141                          6268
# 343                      942788                         12959
# 344                      977910                         17407
# 345                     1007808                         17775
# 346                     1036089                         14885
# 347                     1067006                         13103
# 348                     1081369                          8443
# 349                     1093923                          4315
#
#      prirustkovy_pocet_vylecenych  prirustkovy_pocet_umrti  \
# 340                         12256                      152
# 341                         11142                      152
# 342                          2088                      141
# 343                          2390                      150
# 344                          3801                      180
# 345                          4924                      159
# 346                         14498                      186
# 347                         15923                      196
# 348                         16180                      161
# 349                          8722                      184
#
#      prirustkovy_pocet_provedenych_testu  \
# 340                                 6585
# 341                                13449
# 342                                15322
# 343                                35177
# 344                                44018
# 345                                39049
# 346                                38974
# 347                                38763
# 348                                21081
# 349                                12317
#
#      prirustkovy_pocet_provedenych_ag_testu
# 340                                    5066
# 341                                   15529
# 342                                   14335
# 343                                   55647
# 344                                   35122
# 345                                   29898
# 346                                   28281
# 347                                   30917
# 348                                   14363
# 349                                   12554

# %%
df['datum'].max()
# Out:
# Timestamp('2021-06-30 00:00:00')

# %%
pd.Timestamp.today()
# Out:
# Timestamp('2021-07-01 22:54:17.571814')
